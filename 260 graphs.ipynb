# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rc('axes', titlesize=16)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

# %%
df = pd.read_csv("knockpy_times.csv")

# %%
df
# Out:
#      Unnamed: 0  RAM   function matrix_type    chunk_type  num_cores  \
# 0             0   15        dot      sparse  (1000, 1000)          1
# 1             1    3  transpose      random  (1000, 1000)          8
# 2             2    6  transpose      random          auto          1
# 3             3    1       eigh      random          auto          1
# 4             4   15        inv      random          auto          8
# ..          ...  ...        ...         ...           ...        ...
# 157         157    6        inv      sparse  (1000, 1000)          8
# 158         158    6        dot      sparse  (1000, 1000)          4
# 159         159   15       eigh      sparse  (1000, 1000)          1
# 160         160    6  transpose      sparse          auto          1
# 161         161    3        dot      sparse          auto          4
#
#             time
# 0     294.927341
# 1       9.058634
# 2      16.028720
# 3    1450.546948
# 4     185.569658
# ..           ...
# ...

# %%
df_ram = df.groupby('RAM').mean()
df_ram.reset_index(inplace=True)
sns.set_style("whitegrid")
sns.scatterplot(x='RAM', y='time', data=df_ram).set_title('Average time vs RAM')
# Out:
# Text(0.5, 1.0, 'Average time vs RAM')

# %%
df_1 = df[df['function'] == 'dot']
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.barplot(x='RAM', y='time', hue='num_cores', data=df_1).set_title('Dot function time by RAM and Number of Cores')
ax.set_xlabel("RAM (GB)")
ax.set_ylabel("time (s)")
# Out:
# Text(0, 0.5, 'time (s)')

# %%
df_1 = df[df['function'] == 'eigh']
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.barplot(x='RAM', y='time', hue='num_cores', data=df_1).set_title('Eigh function time by RAM and Number of Cores')
ax.set_xlabel("RAM (GB)")
ax.set_ylabel("time (s)")
# Out:
# Text(0, 0.5, 'time (s)')

# %%
df_1 = df[df['function'] == 'transpose']
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.barplot(x='RAM', y='time', hue='num_cores', data=df_1).set_title('Transpose function time by RAM and Number of Cores')
ax.set_xlabel("RAM (GB)")
ax.set_ylabel("time (s)")
# Out:
# Text(0, 0.5, 'time (s)')

# %%
df_1 = df[df['function'] == 'inv']
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.barplot(x='RAM', y='time', hue='num_cores', data=df_1).set_title('Inverse function time by RAM and Number of Cores')
ax.set_xlabel("RAM (GB)")
ax.set_ylabel("time (s)")
# Out:
# Text(0, 0.5, 'time (s)')

# %% [markdown]
# What if we did a scatterplot with x axis cores, change symbol based on chunk_type, hue on function
# either per unit RAM or a different plot for each value of ram

# %%
df_1 = df[(df['RAM'] == 15)]
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(6, 4)
plot = sns.scatterplot(x='num_cores', y='time', hue='function', style='chunk_type', data=df_1, ax=ax)
plot.set(xlabel="Number of Cores", title="Time by Number of Cores for RAM=15GB", xticks=[1, 4, 8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_1 = df[(df['RAM'] == 15) & (df['function'] == 'dot')]
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(6, 4)
plot = sns.scatterplot(x='num_cores', y='time', color='blue', style='chunk_type', data=df_1, ax=ax)
plot.set(xlabel="Number of Cores", title="Time by Number of Cores for RAM=15GB and Dot function", xticks=[1, 4, 8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_1 = df[(df['RAM'] == 15) & (df['function'] == 'eigh')]
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(6, 4)
plot = sns.scatterplot(x='num_cores', y='time', color='orange', style='chunk_type', data=df_1, ax=ax)
plot.set(xlabel="Number of Cores", title="Time by Number of Cores for RAM=15GB and Eigh function", xticks=[1, 4, 8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_1 = df[(df['RAM'] == 15) & (df['function'] == 'transpose')]
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(6, 4)
plot = sns.scatterplot(x='num_cores', y='time', color='green', style='chunk_type', data=df_1, ax=ax)
plot.set(xlabel="Number of Cores", title="Time by Number of Cores for RAM=15GB and Transpose function", xticks=[1, 4, 8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_1 = df[(df['RAM'] == 15) & (df['function'] == 'inv')]
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(6, 4)
plot = sns.scatterplot(x='num_cores', y='time', color='red', style='chunk_type', data=df_1, ax=ax)
plot.set(xlabel="Number of Cores", title="Time by Number of Cores for RAM=15GB and Inverse function", xticks=[1, 4, 8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df[(df['function']=='inv')&(df['RAM']==3)].sort_values(['num_cores','matrix_type'])
# Out:
#      level_0  index  Unnamed: 0  RAM function matrix_type    chunk_type  \
# 12        12     12          12    3      inv      random          auto
# 63        63     63          63    3      inv      random  (1000, 1000)
# 121      121    121         121    3      inv      sparse          auto
# 131      131    131         131    3      inv      sparse  (1000, 1000)
# 142      142    142         142    3      inv      random          auto
# 109      109    109         109    3      inv      random          auto
# 23        23     23          23    3      inv      sparse          auto
#
#      num_cores         time
# 12           1  1175.591784
# 63           1  2362.179310
# 121          1  1218.112830
# 131          1  1954.332684
# 142          4   412.943657
# 109          8   306.073259
# 23           8   374.072664

# %%
df_f = df.groupby('function').mean()
df_f.reset_index(inplace=True)
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
plot = sns.barplot(x='function', y='time', data=df_f).set_title('Average time by function')
ax.set_ylabel("time (s)")
# Argue for eigh needing a more efficient function within dask
# Out:
# Text(0, 0.5, 'time (s)')

# %%
df_m = df.groupby('matrix_type').mean()
df_m.reset_index(inplace=True)
sns.set_style("whitegrid")
sns.barplot(x='matrix_type', y='time', data=df_m).set_title('Average time by matrix_type')
# Out:
# Text(0.5, 1.0, 'Average time by matrix_type')

# %%
df_c = df.groupby('chunk_type').mean()
df_c.reset_index(inplace=True)
sns.set_style("whitegrid")
sns.barplot(x='chunk_type', y='time', data=df_c).set_title('Average time by chunk_type')
# Out:
# Text(0.5, 1.0, 'Average time by chunk_type')

# %%
df_cores = df
sns.set_style("whitegrid")
sns.scatterplot(x='num_cores', y='time', data=df_cores).set_title('Average time vs num_cores')
# Out:
# Text(0.5, 1.0, 'Average time vs num_cores')

# %%
sns.scatterplot(x='num_cores', y='time', data=df).set_title('Average time vs num_cores')
# Out:
# Text(0.5, 1.0, 'Average time vs num_cores')

# %%
df.groupby('num_cores').count()
# Out:
#            level_0  index  Unnamed: 0  RAM  function  matrix_type  chunk_type  \
# num_cores
# 1               59     59          59   59        59           59          59
# 4               47     47          47   47        47           47          47
# 8               56     56          56   56        56           56          56
#
#            time
# num_cores
# 1            59
# 4            47
# 8            56

# %%
df.groupby(['RAM', 'num_cores']).count()
# Out:
#                level_0  index  Unnamed: 0  function  matrix_type  chunk_type  \
# RAM num_cores
# 1   1               12     12          12        12           12          12
#     4                6      6           6         6            6           6
#     8               10     10          10        10           10          10
# 3   1               15     15          15        15           15          15
#     4               10     10          10        10           10          10
#     8               14     14          14        14           14          14
# 6   1               16     16          16        16           16          16
#     4               15     15          15        15           15          15
#     8               16     16          16        16           16          16
# 15  1               16     16          16        16           16          16
#     4               16     16          16        16           16          16
# ...

# %%
df.groupby('function').count()
# Out:
#            level_0  index  Unnamed: 0  RAM  matrix_type  chunk_type  \
# function
# dot             42     42          42   42           42          42
# eigh            41     41          41   41           41          41
# inv             35     35          35   35           35          35
# transpose       44     44          44   44           44          44
#
#            num_cores  time
# function
# dot               42    42
# eigh              41    41
# inv               35    35
# transpose         44    44

# %%
df[df['chunk_type']]
# Out:
#      level_0  index  Unnamed: 0  RAM   function matrix_type    chunk_type  \
# 0          0      0           0   15        dot      sparse  (1000, 1000)
# 1          1      1           1    3  transpose      random  (1000, 1000)
# 2          2      2           2    6  transpose      random          auto
# 3          3      3           3    1       eigh      random          auto
# 4          4      4           4   15        inv      random          auto
# ..       ...    ...         ...  ...        ...         ...           ...
# 157      157    157         157    6        inv      sparse  (1000, 1000)
# 158      158    158         158    6        dot      sparse  (1000, 1000)
# 159      159    159         159   15       eigh      sparse  (1000, 1000)
# 160      160    160         160    6  transpose      sparse          auto
# 161      161    161         161    3        dot      sparse          auto
#
#      num_cores         time
# 0            1   294.927341
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
sns.set_style('whitegrid')
sns.violinplot(x="chunk_type", y="time", data=df, ax=ax)
ax.set_ylabel("time (s)")
ax.set_xlabel("Chunk Type")
ax.set_title("Distribution of times by chunking type")
# Out:
# Text(0.5, 1.0, 'Distribution of times by chunking type')

# %%
df[df['time']>2500]
# Out:
# Empty DataFrame
# Columns: [level_0, index, Unnamed: 0, RAM, function, matrix_type, chunk_type, num_cores, time]
# Index: []
